# %% [markdown]
# <a href="https://colab.research.google.com/github/sonG1031/pythonOnline/blob/main/20211005_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

fail, big, small, count = 0, 0, 0, 0

while True:
    count += 1

    a = random.randrange(1, 7)
    b = random.randrange(1, 7)
    c = random.randrange(1, 7)

    if a+b+c == 3 or a+b+c == 18:
        fail += 1
    elif a+b+c < 11:
        small += 1
    else:
        big += 1

    print('big확률: {0}, small확률: {1}'.format((big/count)*100, (small/count) * 100))
    time.sleep(0.1)
# Out:
# big확률: 0.0, small확률: 100.0
# big확률: 50.0, small확률: 50.0
# big확률: 66.66666666666666, small확률: 33.33333333333333
# big확률: 50.0, small확률: 50.0
# big확률: 60.0, small확률: 40.0
# big확률: 50.0, small확률: 50.0
# big확률: 42.857142857142854, small확률: 57.14285714285714
# big확률: 37.5, small확률: 62.5
# big확률: 44.44444444444444, small확률: 55.55555555555556
# big확률: 40.0, small확률: 60.0
# big확률: 36.36363636363637, small확률: 54.54545454545454
# big확률: 33.33333333333333, small확률: 50.0
# big확률: 38.46153846153847, small확률: 46.15384615384615
# big확률: 42.857142857142854, small확률: 42.857142857142854
# big확률: 46.666666666666664, small확률: 40.0
# big확률: 43.75, small확률: 43.75
# big확률: 47.05882352941176, small확률: 41.17647058823529
# big확률: 50.0, small확률: 38.88888888888889
# big확률: 52.63157894736842, small확률: 36.84210526315789
# big확률: 55.00000000000001, small확률: 35.0
# big확률: 57.14285714285714, small확률: 33.33333333333333
# big확률: 59.09090909090909, small확률: 31.818181818181817
# ...
